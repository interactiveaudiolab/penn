# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import penne

# %%
loader = penne.data.loader(['ptdb'], 'test')

# %%
for audio, *_ in loader:
    pitch, periodicity, probs = penne.dsp.pyin.from_audio(audio)
    break

# %%
import matplotlib.pyplot as plt
plt.plot(pitch.squeeze())

# %%
plt.plot(periodicity.squeeze())

# %%
import torch
index = 10
probs[torch.isinf(probs)] = 0.
plt.plot(probs[index, :, 0] / probs[index].sum())
